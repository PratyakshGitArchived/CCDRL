# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
#Trying to compare models using pycaret

# %%
# !pip install pycaret

# %%
from pycaret.classification import *
clf1 = setup(data = df, target = 'Class')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_7010be6e_a836_11ea_b9a0_0242ac1c0002row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_7010be6e_a836_11ea_b9a0_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7010be6e_a836_11ea_b9a0_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7010be6e_a836_11ea_b9a0_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7010be6e_a836_11ea_b9a0_0242ac1c0002row0_col1" class="data row0 col1" >1384</td>
#             </tr>
#             <tr>
#                         <th id="T_7010be6e_a836_11ea_b9a0_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_13670594_a83e_11ea_b9a0_0242ac1c0002 th {
#           text-align: left;
#     }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_13670594_a83e_11ea_b9a0_0242ac1c0002row1_col0 {
# ...
